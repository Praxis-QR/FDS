# %% [markdown]
# <a href="https://colab.research.google.com/github/Praxis-QR/FDS/blob/main/Very_Large_Data_Sets_with_Vaex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://github.com/Praxis-QR/BDSN/raw/main/images/KKBanner4Colab_Dec22.png)<br>
#
#
# <hr>
#
# [Prithwis Mukerjee](http://www.linkedin.com/in/prithwis)<br>

# %% [markdown]
# https://vaex.readthedocs.io/en/latest/tutorials.html

# %%
# !pip install vaex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 43 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 58 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 4.5 MB 71.2 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 84.1 MB/s
# ...
#      |████████████████████████████████| 237 kB 73.7 MB/s
# ...
#      |████████████████████████████████| 110 kB 77.9 MB/s
# ...
#      |████████████████████████████████| 510 kB 86.3 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 63.8 MB/s
# ...
#      |████████████████████████████████| 3.7 MB 56.2 MB/s
# ...
#      |████████████████████████████████| 11.7 MB 52.8 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 74.0 MB/s
# ...
#      |████████████████████████████████| 260 kB 78.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 73.1 MB/s
# ...
#      |████████████████████████████████| 2.7 MB 76.6 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 73.8 MB/s
# ...

# %%
import vaex
import warnings; warnings.filterwarnings("ignore")

# %%
df = vaex.open('s3://vaex/taxi/yellow_taxi_2015_f32s.hdf5?anon=true')

print(f'number of rows: {df.shape[0]:,}')
print(f'number of columns: {df.shape[1]}')

long_min = -74.05
long_max = -73.75
lat_min = 40.58
lat_max = 40.90

df.plot(df.pickup_longitude, df.pickup_latitude, f="log1p", limits=[[-74.05, -73.75], [40.58, 40.90]], show=True);
# Out:
# number of rows: 146,112,991
# number of columns: 18

# %%
df = vaex.open('s3://vaex/airline/us_airline_data_1988_2018.hdf5?anon=true')

print(f'number of rows: {df.shape[0]:,}')
print(f'number of columns: {df.shape[1]}')

df.head(5)
# Out:
# number of rows: 183,821,926
# number of columns: 29
#   #    Year    Month    DayOfMonth    DayOfWeek  UniqueCarrier    TailNum      FlightNum  Origin    Dest      CRSDepTime  DepTime    DepDelay    TaxiOut    TaxiIn      CRSArrTime  ArrTime    ArrDelay      Cancelled  CancellationCode      Diverted    CRSElapsedTime  ActualElapsedTime    AirTime      Distance  CarrierDelay    WeatherDelay    NASDelay    SecurityDelay    LateAircraftDelay
#   0    1988        1             8            5  PI               None               930  BGM       ITH             1525  1532       7           --         --                1545  1555       10                    0  None                         0                20  23                   --                 32  --              --              --          --               --
# ...
