# %% [markdown]
# <a href="https://colab.research.google.com/github/Praxis-QR/FDS/blob/main/ColabTurtle_Art.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *
import random
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7657 sha256=b18853fe425dd7155ae357b649fde1ace4515864e2cf3f3245bf3b7b7dcf5ddb
#   Stored in directory: /root/.cache/pip/wheels/0d/ab/65/cc4478508751448dfb4ecb20a6533082855c227dfce8c13902
# Successfully built ColabTurtle
# ...

# %%
def cleanSlate(startX, startY):
    initializeTurtle(initial_window_size=(900,900))
    clear()
    bgcolor('white')
    color('red')
    penup()
    goto(startX, startY)
    pendown()

# %%
#import turtle
cleanSlate(450,450)
#bgcolor('black')
#colormode(255)
speed(10)
for x in range(500): 
    r,b,g=random.randint(0,255),random.randint(0,255),random.randint(0,255)
    pencolor(r,g,b)
    fd(x+50)
    rt(91)
#turtle.exitonclick()
# Out:
#       <svg width="900" height="900">
#         <rect width="100%" height="100%" fill="white"/>
# ...
