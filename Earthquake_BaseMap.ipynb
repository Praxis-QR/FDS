# %% [markdown]
# <a href="https://colab.research.google.com/github/Praxis-QR/FDS/blob/main/Earthquake_BaseMap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![CC-BY-SA](https://licensebuttons.net/l/by-sa/3.0/88x31.png)<br>
# <hr>
#
# ![alt text](https://4.bp.blogspot.com/-gbL5nZDkpFQ/XScFYwoTEII/AAAAAAAAAGY/CcVb_HDLwvs2Brv5T4vSsUcz7O4r2Q79ACK4BGAYYCw/s1600/kk3-header00-beta.png)<br>
#
#
# <hr>
#
# [Prithwis Mukerjee](http://www.linkedin.com/in/prithwis)<br>

# %% [markdown]
# #Basemap - Matplotib <br>
# http://introtopython.org/visualization_earthquakes.html

# %% [markdown]
# # Installation, setup <br>
# Basic Map

# %%
# without this Basemap will not work
# 
#!apt-get install libgeos-3.5.0
# !apt-get install libgeos-dev > /dev/null
#!pip install https://github.com/matplotlib/basemap/archive/master.zip
# !pip -q install basemap
# !pip -q install basemap-data-hires
# Out:
#      |████████████████████████████████| 864 kB 8.6 MB/s
#      |████████████████████████████████| 46 kB 2.4 MB/s
#      |████████████████████████████████| 30.5 MB 67.3 MB/s
#      |████████████████████████████████| 6.3 MB 19.8 MB/s
#      |████████████████████████████████| 91.1 MB 98 kB/s

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np

# %%
# This just lets the output of the following code samples
#  display inline on this page, at an appropriate size.
from pylab import rcParams

# %matplotlib inline
rcParams['figure.figsize'] = (8,6)

# %%
# make sure the value of resolution is a lowercase L,
#  for 'low', not a numeral 1
# for other kinds of maps see https://matplotlib.org/basemap/users/mapsetup.html
my_map = Basemap(projection='ortho', lat_0=22, lon_0=88,
              resolution='l', area_thresh=1000.0)
 
my_map.drawcoastlines()
 
plt.show()

# %%
my_map = Basemap(projection='ortho', lat_0=22, lon_0=88,
              resolution='l', area_thresh=1000.0)
 
my_map.drawcoastlines()
my_map.drawcountries()   # India map is not as per Govt of India
my_map.fillcontinents(color='coral')
 
plt.show()

# %%
my_map = Basemap(projection='ortho', lat_0=22, lon_0=88,
              resolution='l', area_thresh=1000.0)
 
my_map.drawcoastlines()
my_map.drawcountries()   # India map is not as per Govt of India
my_map.drawmapboundary() # not sure what difference did this make
my_map.fillcontinents(color='coral')
 
plt.show()

# %%
my_map = Basemap(projection='ortho', lat_0=22, lon_0=88,
              resolution='l', area_thresh=1000.0)
 
my_map.drawcoastlines()
my_map.drawcountries()   # India map is not as per Govt of India
my_map.drawmapboundary(fill_color='aqua') 
my_map.fillcontinents(color='coral')

my_map.drawmeridians(np.arange(0, 360, 30))
my_map.drawparallels(np.arange(-90, 90, 30))
 
plt.show()

# %%
# for other kinds of maps see https://matplotlib.org/basemap/users/mapsetup.html
my_map = Basemap(projection='robin', lat_0=22, lon_0=88,
              resolution='l', area_thresh=1000.0)
 
my_map.drawcoastlines()
my_map.drawcountries()   # India map is not as per Govt of India
my_map.drawmapboundary(fill_color='aqua') 
my_map.fillcontinents(color='coral',lake_color='aqua')

my_map.drawmeridians(np.arange(0, 360, 30))
my_map.drawparallels(np.arange(-90, 90, 30))
 
plt.show()

# %% [markdown]
# # Zoom

# %%
my_map = Basemap(projection='merc', lat_0=21.74, lon_0=88.203,
    resolution = 'l', area_thresh = 1000.0)
#,
#    llcrnrlon=-136.25, llcrnrlat=56,
#    urcrnrlon=-134.25, urcrnrlat=57.75)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')
my_map.drawmapboundary()
 
my_map.drawmeridians(np.arange(0, 360, 30))
my_map.drawparallels(np.arange(-90, 90, 30))
 
plt.show()

# %%
my_map = Basemap(projection='merc', lat_0=21.74, lon_0=88.203,
    resolution = 'l', area_thresh = 1000.0,
    llcrnrlon=87.5, llcrnrlat=21.0,
    urcrnrlon=89.5, urcrnrlat=23)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')
my_map.drawmapboundary()
 
my_map.drawmeridians(np.arange(0, 360, 30))
my_map.drawparallels(np.arange(-90, 90, 30))
 
plt.show()

# %%
clat = 22.3
clong = 88.3
delta = 1

my_map = Basemap(projection='merc', lat_0=clat, lon_0=clong,
    resolution = 'h', area_thresh = 1000.0,
    llcrnrlon=clong-delta, llcrnrlat=clat-delta,
    urcrnrlon=clong+delta, urcrnrlat=clat+delta)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')
my_map.drawmapboundary()
 
my_map.drawmeridians(np.arange(0, 360, 30))
my_map.drawparallels(np.arange(-90, 90, 30))
 
plt.show()

# %%
clat = 21.8
clong = 88.3
delta = 0.3

my_map = Basemap(projection='merc', lat_0=clat, lon_0=clong,
    resolution = 'h', area_thresh = 0.01,
    llcrnrlon=clong-delta, llcrnrlat=clat-delta,
    urcrnrlon=clong+delta, urcrnrlat=clat+delta)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')
my_map.drawmapboundary()
 
my_map.drawmeridians(np.arange(0, 360, 30))
my_map.drawparallels(np.arange(-90, 90, 30))
 
plt.show()

# %%
clat = 21.65
clong = 88.2
delta = 0.15

my_map = Basemap(projection='merc', lat_0=clat, lon_0=clong,
    resolution = 'h', area_thresh = 0.001,
    llcrnrlon=clong-delta, llcrnrlat=clat-delta,
    urcrnrlon=clong+delta, urcrnrlat=clat+delta)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')
my_map.drawmapboundary()
 
my_map.drawmeridians(np.arange(0, 360, 30))
my_map.drawparallels(np.arange(-90, 90, 30))


lon = 88.258092
lat = 21.565824
x,y = my_map(lon, lat)
my_map.plot(x, y, 'bo', markersize=12)
 
plt.show()

# %%
clat = 21.65
clong = 88.2
delta = 0.15

my_map = Basemap(projection='merc', lat_0=clat, lon_0=clong,
    resolution = 'h', area_thresh = 0.001,
    llcrnrlon=clong-delta, llcrnrlat=clat-delta,
    urcrnrlon=clong+delta, urcrnrlat=clat+delta)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')
my_map.drawmapboundary()
 
#my_map.drawmeridians(np.arange(0, 360, 30))
#my_map.drawparallels(np.arange(-90, 90, 30))


lons = [88.258092, 88.224985]
lats = [21.565824, 21.768899]
x,y = my_map(lons, lats)
my_map.plot(x, y, 'bo', markersize=10)

 
plt.show()

# %%
clat = 21.65
clong = 88.2
delta = 0.15

my_map = Basemap(projection='merc', lat_0=clat, lon_0=clong,
    resolution = 'h', area_thresh = 0.001,
    llcrnrlon=clong-delta, llcrnrlat=clat-delta,
    urcrnrlon=clong+delta, urcrnrlat=clat+delta)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')
my_map.drawmapboundary()
 
#my_map.drawmeridians(np.arange(0, 360, 30))
#my_map.drawparallels(np.arange(-90, 90, 30))


lons = [88.258092, 88.224985]
lats = [21.565824, 21.768899]
x,y = my_map(lons, lats)
my_map.plot(x, y, 'bo', markersize=10)

labels = ['Bakkhali', 'Namkhana']
for label, xpt, ypt in zip(labels, x, y):
    plt.text(xpt, ypt, label)

 
plt.show()

# %%
clat = 21.65
clong = 88.2
delta = 0.15

my_map = Basemap(projection='merc', lat_0=clat, lon_0=clong,
    resolution = 'h', area_thresh = 0.001,
    llcrnrlon=clong-delta, llcrnrlat=clat-delta,
    urcrnrlon=clong+delta, urcrnrlat=clat+delta)
 
my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='coral')
my_map.drawmapboundary()
 
#my_map.drawmeridians(np.arange(0, 360, 30))
#my_map.drawparallels(np.arange(-90, 90, 30))


lons = [88.258092, 88.224985]
lats = [21.565824, 21.768899]
x,y = my_map(lons, lats)
my_map.plot(x, y, 'bo', markersize=10)

x_offsets = [500, 500]
y_offsets = [500, -700]

labels = ['Bakkhali', 'Namkhana']

for label, xpt, ypt, x_offset, y_offset in zip(labels, x, y, x_offsets, y_offsets):
    plt.text(xpt+x_offset, ypt+y_offset, label)

plt.show()

# %% [markdown]
# # Earthquake Plotting

# %%
# !wget -O earthquake-data.csv -q http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_week.csv

# %%
# !ls -al
# Out:
# total 536
# drwxr-xr-x 1 root root   4096 Oct 13 13:24 .
# drwxr-xr-x 1 root root   4096 Oct 13 13:19 ..
# drwxr-xr-x 4 root root   4096 Oct  7 13:34 .config
# -rw-r--r-- 1 root root 262659 Oct 13 13:24 earthquake-data.csv
# -rw-r--r-- 1 root root 262659 Oct 13 13:24 -q
# drwxr-xr-x 1 root root   4096 Oct  7 13:35 sample_data

# %%
import csv

# Open the earthquake data file.
filename = 'earthquake-data.csv'

# Create empty lists for the latitudes and longitudes.
lats, lons = [], []

# Read through the entire file, skip the first line,
#  and pull out just the lats and lons.
with open(filename) as f:
    # Create a csv reader object.
    reader = csv.reader(f)
    
    # Ignore the header row.
    next(reader)
    
    # Store the latitudes and longitudes in the appropriate lists.
    for row in reader:
        lats.append(float(row[1]))
        lons.append(float(row[2]))
        
# Display the first 5 lats and lons.
print('lats', lats[0:5])
print('lons', lons[0:5])
# Out:
# lats [63.5525, 35.9005, 62.0385, 55.7876, 19.1956672668457]
# lons [-147.2792, -117.7538333, -146.89, -159.6897, -155.492340087891]

# %%
import csv

# Open the earthquake data file.
filename = 'earthquake-data.csv'

# Create empty lists for the latitudes and longitudes.
lats, lons = [], []

# Read through the entire file, skip the first line,
#  and pull out just the lats and lons.
with open(filename) as f:
    # Create a csv reader object.
    reader = csv.reader(f)
    
    # Ignore the header row.
    next(reader)
    
    # Store the latitudes and longitudes in the appropriate lists.
    for row in reader:
        lats.append(float(row[1]))
        lons.append(float(row[2]))
 
# --- Build Map ---
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 
eq_map = Basemap(projection='robin', resolution = 'l', area_thresh = 1000.0,
              lat_0=0, lon_0=-130)
eq_map.drawcoastlines()
eq_map.drawcountries()
eq_map.fillcontinents(color = 'gray')
eq_map.drawmapboundary()
eq_map.drawmeridians(np.arange(0, 360, 30))
eq_map.drawparallels(np.arange(-90, 90, 30))
 
x,y = eq_map(lons, lats)
eq_map.plot(x, y, 'ro', markersize=6)
 
plt.show()

# %% [markdown]
# # Use Pandas instead ...

# %%
import pandas as pd

df = pd.read_csv("earthquake-data.csv")
print(df.head(3))
# Out:
#                        time  latitude   longitude  depth   mag magType   nst  \
# 0  2022-10-13T13:19:32.147Z   63.5525 -147.279200    0.0  1.80      ml   NaN
# 1  2022-10-13T13:01:36.710Z   35.9005 -117.753833    8.8  1.47      ml  16.0
# 2  2022-10-13T13:01:34.960Z   62.0385 -146.890000   56.6  1.40      ml   NaN
#
#      gap     dmin   rms  ...                   updated  \
# 0    NaN      NaN  0.49  ...  2022-10-13T13:21:34.873Z
# 1  104.0  0.07118  0.18  ...  2022-10-13T13:12:35.230Z
# 2    NaN      NaN  0.64  ...  2022-10-13T13:03:52.707Z
#
#                               place        type horizontalError depthError  \
# 0  83 km ESE of Denali Park, Alaska  earthquake             NaN       0.50
# 1       14km ESE of Little Lake, CA  earthquake            0.43       0.92
# 2       8 km NW of Nelchina, Alaska  earthquake             NaN       1.20
#
#    magError  magNst     status  locationSource magSource
# 0       NaN     NaN  automatic              ak        ak
# ...

# %%
lats = list(df.latitude)
lons = list(df.longitude)
print('lats', lats[0:5])
print('lons', lons[0:5])
# Out:
# lats [63.5525, 35.9005, 62.0385, 55.7876, 19.1956672668457]
# lons [-147.2792, -117.7538333, -146.89, -159.6897, -155.492340087891]

# %%
import pandas as pd

df = pd.read_csv("earthquake-data.csv")

# Create empty lists for the latitudes and longitudes.
lats = list(df.latitude)
lons = list(df.longitude)

#print('lats', lats[0:5])
#print('lons', lons[0:5])
 
# --- Build Map ---
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
 
eq_map = Basemap(projection='robin', resolution = 'l', area_thresh = 1000.0,
              lat_0=0, lon_0=-130)
eq_map.drawcoastlines()
eq_map.drawcountries()
eq_map.fillcontinents(color = 'gray')
eq_map.drawmapboundary()
eq_map.drawmeridians(np.arange(0, 360, 30))
eq_map.drawparallels(np.arange(-90, 90, 30))
 
x,y = eq_map(lons, lats)
eq_map.plot(x, y, 'ro', markersize=6)
 
plt.show()

# %%
# Create empty lists for the latitudes and longitudes.
lats = list(df.latitude)
lons = list(df.longitude)
mags = list(df.mag)

print('lats', lats[0:5])
print('lons', lons[0:5])
print('mags', mags[0:5])
# Out:
# lats [63.5525, 35.9005, 62.0385, 55.7876, 19.1956672668457]
# lons [-147.2792, -117.7538333, -146.89, -159.6897, -155.492340087891]
# mags [1.8, 1.47, 1.4, 3.4, 2.00999999]

# %%
eq_map = Basemap(projection='robin', resolution = 'l', area_thresh = 1000.0,
              lat_0=0, lon_0=-130)
eq_map.drawcoastlines()
eq_map.drawcountries()
eq_map.fillcontinents(color = 'gray')
eq_map.drawmapboundary()
eq_map.drawmeridians(np.arange(0, 360, 30))
eq_map.drawparallels(np.arange(-90, 90, 30))

min_marker_size = 2.5
for lon, lat, mag in zip(lons, lats, mags):
    x,y = eq_map(lon, lat)
    msize = mag * min_marker_size
    eq_map.plot(x, y, 'ro', markersize=msize)
 
plt.show()

# %%
def get_marker_color(magnitude):
    # Returns green for small earthquakes, yellow for moderate
    #  earthquakes, and red for significant earthquakes.
    if magnitude < 3.0:
        return ('go')
    elif magnitude < 5.0:
        return ('yo')
    else:
        return ('ro')

# %%
eq_map = Basemap(projection='robin', resolution = 'l', area_thresh = 1000.0,
              lat_0=0, lon_0=-130)
eq_map.drawcoastlines()
eq_map.drawcountries()
eq_map.fillcontinents(color = 'gray')
eq_map.drawmapboundary()
eq_map.drawmeridians(np.arange(0, 360, 30))
eq_map.drawparallels(np.arange(-90, 90, 30))
 
min_marker_size = 2.5
for lon, lat, mag in zip(lons, lats, mags):
    x,y = eq_map(lon, lat)
    msize = mag * min_marker_size
    marker_string = get_marker_color(mag)
    eq_map.plot(x, y, marker_string, markersize=msize)
 
plt.show()

# %%
# Create lists of data
lats = list(df.latitude)
lons = list(df.longitude)
mags = list(df.mag)

time = list(df.time)

print('lats', lats[0:5])
print('lons', lons[0:5])
print('mags', mags[0:5])

print('first quake ',time[0], ' last quake ', time[len(time)-1] )
# Out:
# lats [63.5525, 35.9005, 62.0385, 55.7876, 19.1956672668457]
# lons [-147.2792, -117.7538333, -146.89, -159.6897, -155.492340087891]
# mags [1.8, 1.47, 1.4, 3.4, 2.00999999]
# first quake  2022-10-13T13:19:32.147Z  last quake  2022-10-06T13:47:06.150Z

# %%
eq_map = Basemap(projection='robin', resolution = 'l', area_thresh = 1000.0,
              lat_0=0, lon_0=-130)
eq_map.drawcoastlines()
eq_map.drawcountries()
eq_map.fillcontinents(color = 'gray')
eq_map.drawmapboundary()
eq_map.drawmeridians(np.arange(0, 360, 30))
eq_map.drawparallels(np.arange(-90, 90, 30))
 
min_marker_size = 2.5
for lon, lat, mag in zip(lons, lats, mags):
    x,y = eq_map(lon, lat)
    msize = mag * min_marker_size
    marker_string = get_marker_color(mag)
    eq_map.plot(x, y, marker_string, markersize=msize)

title_string = "Earthquakes of Magnitude 1.0 or Greater\n"
title_string += time[len(time)-1][:10] 
title_string += " to "
title_string += time[0][:10] 

plt.title(title_string)
    
plt.show()

# %%
# Make this plot larger.
plt.figure(figsize=(16,12))

eq_map = Basemap(projection='robin', resolution = 'l', area_thresh = 1000.0,
              lat_0=0, lon_0=-130)
eq_map.drawcoastlines()
eq_map.drawcountries()
eq_map.fillcontinents(color = 'gray')
eq_map.drawmapboundary()
eq_map.drawmeridians(np.arange(0, 360, 30))
eq_map.drawparallels(np.arange(-90, 90, 30))
 
min_marker_size = 2.5
for lon, lat, mag in zip(lons, lats, mags):
    x,y = eq_map(lon, lat)
    msize = mag * min_marker_size
    marker_string = get_marker_color(mag)
    eq_map.plot(x, y, marker_string, markersize=msize)

title_string = "Earthquakes of Magnitude 1.0 or Greater\n"
title_string += time[len(time)-1][:10] 
title_string += " to "
title_string += time[0][:10] 

plt.title(title_string)
    
plt.show()

# %%
# Make this plot larger.
plt.figure(figsize=(16,12))

eq_map = Basemap(projection='robin', resolution = 'l', area_thresh = 1000.0,
              lat_0=0, lon_0=-130)
eq_map.drawcoastlines()
eq_map.drawcountries()
#eq_map.fillcontinents(color = 'gray')
eq_map.bluemarble()
eq_map.drawmapboundary()
eq_map.drawmeridians(np.arange(0, 360, 30))
eq_map.drawparallels(np.arange(-90, 90, 30))
 
min_marker_size = 2.25
for lon, lat, mag in zip(lons, lats, mags):
    x,y = eq_map(lon, lat)
    msize = mag * min_marker_size
    marker_string = get_marker_color(mag)
    eq_map.plot(x, y, marker_string, markersize=msize)

title_string = "Earthquakes of Magnitude 1.0 or Greater\n"
title_string += time[len(time)-1][:10] 
title_string += " to "
title_string += time[0][:10] 

plt.title(title_string)
    
plt.show()

# %% [markdown]
# #Chronobooks <br>
# Two science fiction novels by Prithwis Mukerjee. A dystopian Earth. A technocratic society managed by artificial intelligence. Escape and epiphany on Mars. Can man and machine, carbon and silicon explore and escape into other dimensions of existence? An Indic perspective rooted in Advaita Vedanta and the Divine Feminine.  [More information](http://bit.ly/chronobooks) <br>
# ![alt text](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEg8qElM73l6qtmIS1VTUgsLLhyoGnbWGDq8g-v-g2iW1xr-IRr7FT9WW4tnKDY2sE1rJKPl7sp_p_f6ipEs-__eYU7V0SRuoLlhkopL063bEPqUTiC4lrM4toFMgaf7kpxE2m5niHwn7jZwb9ktv8OdO7OIwPL9xyyF-SiSuQE2SRemLVQRCalwDnQgdg/s16000/CTCYFooter-1.png)
