# %% [markdown]
# <a href="https://colab.research.google.com/github/Praxis-QR/FDS/blob/main/Movies_Database_Excel_%26_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![alt text](https://github.com/Praxis-QR/RDWH/raw/main/images/YantraJaalBanner.png)<br>
#
#
# <hr>
#
# [Prithwis Mukerjee](http://www.linkedin.com/in/prithwis)<br>

# %%
from datetime import datetime
import pytz
print('ॐ श्री सरस्वत्यै नमः',datetime.now(pytz.timezone('Asia/Calcutta')))
# !python --version
# !lsb_release -a
# Out:
# ॐ श्री सरस्वत्यै नमः 2024-10-28 12:13:28.742682+05:30
# Python 3.10.12
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.3 LTS
# Release:	22.04
# Codename:	jammy

# %% [markdown]
# # Pandas and Excel
# **Reference** : https://www.dataquest.io/blog/excel-and-pandas/

# %%
#Not required anymore
#!pip install xlrd==1.2.0

# %%
import pandas as pd

# %% [markdown]
# ##Get data

# %% [markdown]
# ### Scenario 1 - download and read local

# %%
# !wget -O movies.xls -q  https://github.com/Praxis-QR/FDS/blob/main/data/movies.xls?raw=true
excel_file = 'movies.xls'
movies = pd.read_excel(excel_file)
movies.shape
# Out:
# (1338, 25)

# %%
movies.head(2)
# Out:
#                                                Title  Year             Genres  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916  Drama|History|War
# 1                    Over the Hill to the Poorhouse   1920        Crime|Drama
#
#   Language Country Content Rating  Duration  Aspect Ratio    Budget  \
# 0      NaN     USA      Not Rated       123          1.33  385907.0
# 1      NaN     USA            NaN       110          1.33  100000.0
#
#    Gross Earnings  ... Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 0             NaN  ...                      436                       22
# 1       3000000.0  ...                        2                        2
#
#   Facebook Likes - Actor 3 Facebook Likes - cast Total  \
# 0                      9.0                         481
# 1                      0.0                           4
#
#    Facebook likes - Movie  Facenumber in posters  User Votes  \
# 0                     691                      1       10718
# ...

# %% [markdown]
# ### Scenario 2 - remote file
# Get data from a remote site, without downloading

# %%
remote_excel_file = 'https://github.com/Praxis-QR/FDS/blob/main/data/movies.xls?raw=true'
movies2 = pd.read_excel(remote_excel_file)
movies2.shape
# Out:
# (1338, 25)

# %%
movies2.head(2)
# Out:
#                                                Title  Year             Genres  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916  Drama|History|War
# 1                    Over the Hill to the Poorhouse   1920        Crime|Drama
#
#   Language Country Content Rating  Duration  Aspect Ratio    Budget  \
# 0      NaN     USA      Not Rated       123          1.33  385907.0
# 1      NaN     USA            NaN       110          1.33  100000.0
#
#    Gross Earnings  ... Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 0             NaN  ...                      436                       22
# 1       3000000.0  ...                        2                        2
#
#   Facebook Likes - Actor 3 Facebook Likes - cast Total  \
# 0                      9.0                         481
# 1                      0.0                           4
#
#    Facebook likes - Movie  Facenumber in posters  User Votes  \
# 0                     691                      1       10718
# ...

# %% [markdown]
# ### Scenario 3 -- Read some columns

# %%
excel_file = 'movies.xls'
movies3 = pd.read_excel(excel_file, usecols=[1,2,3,4,5,6])
movies3.head(3)
# Out:
#    Year             Genres Language Country Content Rating  Duration
# 0  1916  Drama|History|War      NaN     USA      Not Rated       123
# 1  1920        Crime|Drama      NaN     USA            NaN       110
# 2  1925  Drama|Romance|War      NaN     USA      Not Rated       151

# %%
movies3.shape
# Out:
# (1338, 6)

# %% [markdown]
# ### Scenario 3 - Sheet by Sheet

# %%
excel_file = 'movies.xls'
movies_sheet1 = pd.read_excel(excel_file, sheet_name=0, index_col=0)
movies_sheet1.head(2)
# Out:
#                                                    Year             Genres  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916  Drama|History|War
# Over the Hill to the Poorhouse                     1920        Crime|Drama
#
#                                                   Language Country  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       NaN     USA
# Over the Hill to the Poorhouse                         NaN     USA
#
#                                                   Content Rating  Duration  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       Not Rated       123
# Over the Hill to the Poorhouse                               NaN       110
#
#                                                    Aspect Ratio    Budget  \
# Title
# Intolerance: Love's Struggle Throughout the Ages           1.33  385907.0
# Over the Hill to the Poorhouse                             1.33  100000.0
#
# ...

# %%
#movies_sheet1.info()

# %%
excel_file = 'movies.xls'
movies_sheet2 = pd.read_excel(excel_file, sheet_name=1, index_col=0)
movies_sheet2.head(2)
# Out:
#                  Year                   Genres Language Country  \
# Title
# 102 Dalmatians   2000  Adventure|Comedy|Family  English     USA
# 28 Days          2000             Comedy|Drama  English     USA
#
#                 Content Rating  Duration  Aspect Ratio      Budget  \
# Title
# 102 Dalmatians               G     100.0          1.85  85000000.0
# 28 Days                  PG-13     103.0          1.37  43000000.0
#
#                  Gross Earnings      Director  ... Facebook Likes - Actor 1  \
# Title                                          ...
# 102 Dalmatians       66941559.0    Kevin Lima  ...                   2000.0
# 28 Days              37035515.0  Betty Thomas  ...                  12000.0
#
#                 Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# Title
# 102 Dalmatians                     795.0                    439.0
# 28 Days                          10000.0                    664.0
#
# ...

# %%
excel_file = 'movies.xls'
movies_sheet3 = pd.read_excel(excel_file, sheet_name=2, index_col=0)
movies_sheet3.head(2)
# Out:
#                 Year                              Genres Language Country  \
# Title
# 127 Hours     2010.0  Adventure|Biography|Drama|Thriller  English     USA
# 3 Backyards   2010.0                               Drama  English     USA
#
#              Content Rating  Duration  Aspect Ratio      Budget  \
# Title
# 127 Hours                 R      94.0          1.85  18000000.0
# 3 Backyards               R      88.0           NaN    300000.0
#
#               Gross Earnings         Director  ... Facebook Likes - Actor 1  \
# Title                                          ...
# 127 Hours         18329466.0      Danny Boyle  ...                  11000.0
# 3 Backyards              NaN  Eric Mendelsohn  ...                    795.0
#
#              Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# Title
# 127 Hours                       642.0                    223.0
# 3 Backyards                     659.0                    301.0
#
# ...

# %%
#Three separate dataframes

movies_sheet3.shape, movies_sheet2.shape, movies_sheet1.shape
# Out:
# ((1604, 24), (2100, 24), (1338, 24))

# %%
#Being merged into one
#
movies = pd.concat([movies_sheet1, movies_sheet2, movies_sheet3])
movies.shape
# Out:
# (5042, 24)

# %%
movies.head(2)
# Out:
#                                                      Year             Genres  \
# Title
# Intolerance: Love's Struggle Throughout the Ages   1916.0  Drama|History|War
# Over the Hill to the Poorhouse                     1920.0        Crime|Drama
#
#                                                   Language Country  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       NaN     USA
# Over the Hill to the Poorhouse                         NaN     USA
#
#                                                   Content Rating  Duration  \
# Title
# Intolerance: Love's Struggle Throughout the Ages       Not Rated     123.0
# Over the Hill to the Poorhouse                               NaN     110.0
#
#                                                    Aspect Ratio    Budget  \
# Title
# Intolerance: Love's Struggle Throughout the Ages           1.33  385907.0
# Over the Hill to the Poorhouse                             1.33  100000.0
#
# ...

# %% [markdown]
# ### Scenario 4 Sheet by Sheet

# %%
#Read ALL sheets
#
excel_file = 'movies.xls'
xlsx = pd.ExcelFile(excel_file)
movies_sheets = []
for sheet in xlsx.sheet_names:
   movies_sheets.append(xlsx.parse(sheet))
movies = pd.concat(movies_sheets)
movies.shape
# Out:
# (5042, 25)

# %%
movies.head(2)
# Out:
#                                                Title    Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916.0
# 1                    Over the Hill to the Poorhouse   1920.0
#
#               Genres Language Country Content Rating  Duration  Aspect Ratio  \
# 0  Drama|History|War      NaN     USA      Not Rated     123.0          1.33
# 1        Crime|Drama      NaN     USA            NaN     110.0          1.33
#
#      Budget  Gross Earnings  ... Facebook Likes - Actor 1  \
# 0  385907.0             NaN  ...                    436.0
# 1  100000.0       3000000.0  ...                      2.0
#
#   Facebook Likes - Actor 2 Facebook Likes - Actor 3  \
# 0                     22.0                      9.0
# 1                      2.0                      0.0
#
#   Facebook Likes - cast Total  Facebook likes - Movie  Facenumber in posters  \
# 0                         481                     691                    1.0
# ...

# %% [markdown]
# ### Scenario 5 - Skip Extra / Junk Lines

# %%
ExcelURL = 'https://github.com/Praxis-QR/FDS/raw/main/data/OfficeSupplies_ExtraLines.xlsx'
df_Incorrect = pd.read_excel(ExcelURL)
df_Incorrect.head(10)
# Out:
#        Praxis Business School Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0  Sample Data for FDS Course        NaN        NaN        NaN        NaN
# 1                         NaN        NaN        NaN        NaN        NaN
# 2       Created on 2 Nov 2023        NaN        NaN        NaN        NaN
# 3                         NaN        NaN        NaN        NaN        NaN
# 4                   OrderDate     Region        Rep       Item      Units
# 5         2014-07-04 00:00:00       East    Richard    Pen Set         62
# 6         2014-07-12 00:00:00       East       Nick     Binder         29
# 7         2014-07-21 00:00:00    Central     Morgan    Pen Set         55
# 8         2014-07-29 00:00:00       East      Susan     Binder         81
# 9         2014-08-07 00:00:00    Central    Matthew    Pen Set         42
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4  Unit Price
# 5        4.99
# 6        1.99
# 7       12.49
# ...

# %%
ExcelURL = 'https://github.com/Praxis-QR/FDS/raw/main/data/OfficeSupplies_ExtraLines.xlsx'
df_Correct = pd.read_excel(ExcelURL,skiprows=5)
df_Correct.head(10)
# Out:
#    OrderDate   Region      Rep     Item  Units  Unit Price
# 0 2014-07-04     East  Richard  Pen Set     62        4.99
# 1 2014-07-12     East     Nick   Binder     29        1.99
# 2 2014-07-21  Central   Morgan  Pen Set     55       12.49
# 3 2014-07-29     East    Susan   Binder     81       19.99
# 4 2014-08-07  Central  Matthew  Pen Set     42       23.95
# 5 2014-08-15     East  Richard   Pencil     35        4.99
# 6 2014-08-24     West    James     Desk      3      275.00
# 7 2014-09-01  Central    Smith     Desk      2      125.00
# 8 2014-09-10  Central     Bill   Pencil      7        1.29
# 9 2014-09-18     East  Richard  Pen Set     16       15.99

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Convert Year to string

# %%
movies['Year'].unique()
# Out:
# array([1916., 1920., 1925., 1927., 1929., 1930., 1932., 1933., 1934.,
#        1935., 1936., 1937., 1938., 1939., 1940., 1941., 1942., 1943.,
#        1944., 1945., 1946., 1947., 1948., 1949., 1950., 1951., 1952.,
#        1953., 1954., 1955., 1956., 1957., 1958., 1959., 1960., 1961.,
#        1962., 1963., 1964., 1965., 1966., 1967., 1968., 1969., 1970.,
#        1971., 1972., 1973., 1974., 1975., 1976., 1977., 1978., 1979.,
#        1980., 1981., 1982., 1983., 1984., 1985., 1986., 1987., 1988.,
#        1989., 1990., 1991., 1992., 1993., 1994., 1995., 1996., 1997.,
#        1998., 1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006.,
#        2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015.,
#        2016.,   nan])

# %%
len(movies['Year'].unique())
# Out:
# 92

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5042 entries, 0 to 1603
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        5042 non-null   object
#  1   Year                         4935 non-null   float64
#  2   Genres                       5042 non-null   object
#  3   Language                     5029 non-null   object
#  4   Country                      5038 non-null   object
#  5   Content Rating               4740 non-null   object
#  6   Duration                     5028 non-null   float64
#  7   Aspect Ratio                 4714 non-null   float64
#  8   Budget                       4551 non-null   float64
#  9   Gross Earnings               4159 non-null   float64
#  10  Director                     4938 non-null   object
#  11  Actor 1                      5035 non-null   object
#  12  Actor 2                      5029 non-null   object
# ...

# %%
movies['Year'] = movies['Year'].astype(str)

# %%
#movies.info()

# %%
movies['Year'].unique()
# Out:
# array(['1916.0', '1920.0', '1925.0', '1927.0', '1929.0', '1930.0',
#        '1932.0', '1933.0', '1934.0', '1935.0', '1936.0', '1937.0',
#        '1938.0', '1939.0', '1940.0', '1941.0', '1942.0', '1943.0',
#        '1944.0', '1945.0', '1946.0', '1947.0', '1948.0', '1949.0',
#        '1950.0', '1951.0', '1952.0', '1953.0', '1954.0', '1955.0',
#        '1956.0', '1957.0', '1958.0', '1959.0', '1960.0', '1961.0',
#        '1962.0', '1963.0', '1964.0', '1965.0', '1966.0', '1967.0',
#        '1968.0', '1969.0', '1970.0', '1971.0', '1972.0', '1973.0',
#        '1974.0', '1975.0', '1976.0', '1977.0', '1978.0', '1979.0',
#        '1980.0', '1981.0', '1982.0', '1983.0', '1984.0', '1985.0',
#        '1986.0', '1987.0', '1988.0', '1989.0', '1990.0', '1991.0',
#        '1992.0', '1993.0', '1994.0', '1995.0', '1996.0', '1997.0',
#        '1998.0', '1999.0', '2000.0', '2001.0', '2002.0', '2003.0',
#        '2004.0', '2005.0', '2006.0', '2007.0', '2008.0', '2009.0',
# ...

# %%
movies['Year'] = movies['Year'].str[:4]
movies['Year'].unique()
# Out:
# array(['1916', '1920', '1925', '1927', '1929', '1930', '1932', '1933',
#        '1934', '1935', '1936', '1937', '1938', '1939', '1940', '1941',
#        '1942', '1943', '1944', '1945', '1946', '1947', '1948', '1949',
#        '1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957',
#        '1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', 'nan'], dtype=object)

# %%
movies.isna().sum()
# Out:
# Title                            0
# Year                             0
# Genres                           0
# Language                        13
# Country                          4
# Content Rating                 302
# Duration                        14
# Aspect Ratio                   328
# Budget                         491
# Gross Earnings                 883
# Director                       104
# Actor 1                          7
# Actor 2                         13
# Actor 3                         22
# Facebook Likes - Director      104
# Facebook Likes - Actor 1         7
# Facebook Likes - Actor 2        13
# Facebook Likes - Actor 3        22
# Facebook Likes - cast Total      0
# Facebook likes - Movie           0
# Facenumber in posters           13
# User Votes                       0
# Reviews by Users                20
# Reviews by Crtiics              49
# IMDB Score                       0
# dtype: int64

# %%
movies.loc[movies['Year'] == 'nan','Year'] = '2999'

# %%
movies['Year'].unique()
# Out:
# array(['1916', '1920', '1925', '1927', '1929', '1930', '1932', '1933',
#        '1934', '1935', '1936', '1937', '1938', '1939', '1940', '1941',
#        '1942', '1943', '1944', '1945', '1946', '1947', '1948', '1949',
#        '1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957',
#        '1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981',
#        '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2999'], dtype=object)

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5042 entries, 0 to 1603
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        5042 non-null   object
#  1   Year                         5042 non-null   object
#  2   Genres                       5042 non-null   object
#  3   Language                     5029 non-null   object
#  4   Country                      5038 non-null   object
#  5   Content Rating               4740 non-null   object
#  6   Duration                     5028 non-null   float64
#  7   Aspect Ratio                 4714 non-null   float64
#  8   Budget                       4551 non-null   float64
#  9   Gross Earnings               4159 non-null   float64
#  10  Director                     4938 non-null   object
#  11  Actor 1                      5035 non-null   object
#  12  Actor 2                      5029 non-null   object
# ...

# %% [markdown]
# ### Convert Reviews to Integer

# %%
movies.fillna({'Reviews by Users':0.0,'Reviews by Crtiics':0.0}, inplace=True)

# %%
movies = movies.astype({"Reviews by Users":"int","Reviews by Crtiics":"int"})

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5042 entries, 0 to 1603
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        5042 non-null   object
#  1   Year                         5042 non-null   object
#  2   Genres                       5042 non-null   object
#  3   Language                     5029 non-null   object
#  4   Country                      5038 non-null   object
#  5   Content Rating               4740 non-null   object
#  6   Duration                     5028 non-null   float64
#  7   Aspect Ratio                 4714 non-null   float64
#  8   Budget                       4551 non-null   float64
#  9   Gross Earnings               4159 non-null   float64
#  10  Director                     4938 non-null   object
#  11  Actor 1                      5035 non-null   object
#  12  Actor 2                      5029 non-null   object
# ...

# %%
movies.head(2)
# Out:
#                                                Title  Year             Genres  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916  Drama|History|War
# 1                    Over the Hill to the Poorhouse   1920        Crime|Drama
#
#   Language Country Content Rating  Duration  Aspect Ratio    Budget  \
# 0      NaN     USA      Not Rated     123.0          1.33  385907.0
# 1      NaN     USA            NaN     110.0          1.33  100000.0
#
#    Gross Earnings  ... Facebook Likes - Actor 1 Facebook Likes - Actor 2  \
# 0             NaN  ...                    436.0                     22.0
# 1       3000000.0  ...                      2.0                      2.0
#
#   Facebook Likes - Actor 3 Facebook Likes - cast Total  \
# 0                      9.0                         481
# 1                      0.0                           4
#
#    Facebook likes - Movie  Facenumber in posters  User Votes  \
# 0                     691                    1.0       10718
# ...

# %% [markdown]
# ##Analysis

# %% [markdown]
# ### Sort by Gross Earnings

# %%
movies.sort_values(['Gross Earnings'],ascending = False)[['Year','Title',"Gross Earnings"]].head(5)
# Out:
#       Year            Title  Gross Earnings
# 1867  2009          Avatar      760505847.0
# 1027  1997         Titanic      658672302.0
# 1263  2015  Jurassic World      652177271.0
# 610   2012    The Avengers      623279547.0
# 611   2012    The Avengers      623279547.0

# %%
movies.sort_values(['Gross Earnings'],ascending = False)[['Year','Title',"Gross Earnings"]].head(5).plot(
    x= 'Title',
    y= 'Gross Earnings',
    kind="barh")
# Out:
# <Axes: ylabel='Title'>

# %%
movies.sort_values(['Gross Earnings'],ascending = False)[['Year','Title',"Gross Earnings"]].head(5).plot(
    x= 'Title',
    y= 'Gross Earnings',
    kind="bar")
# Out:
# <Axes: xlabel='Title'>

# %% [markdown]
# ### Net Earnings

# %%
movies["Net Earnings"] = movies["Gross Earnings"] - movies["Budget"]

# %%
movies.head(5)
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated     123.0
# 1          Crime|Drama      NaN      USA            NaN     110.0
# 2    Drama|Romance|War      NaN      USA      Not Rated     151.0
# 3         Drama|Sci-Fi   German  Germany      Not Rated     145.0
# 4  Crime|Drama|Romance   German  Germany      Not Rated     110.0
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 2  \
# 0          1.33   385907.0             NaN  ...                     22.0
# ...

# %%
movies.sort_values(['Net Earnings'],ascending = False)[['Year','Title',"Net Earnings"]].head(10)
# Out:
#       Year                                       Title  Net Earnings
# 1867  2009                                     Avatar    523505847.0
# 1263  2015                             Jurassic World    502177271.0
# 1027  1997                                    Titanic    458672302.0
# 226   1977         Star Wars: Episode IV - A New Hope    449935665.0
# 328   1982                 E.T. the Extra-Terrestrial    424449459.0
# 610   2012                               The Avengers    403279547.0
# 611   2012                               The Avengers    403279547.0
# 737   1994                              The Lion King    377783777.0
# 1281  1999  Star Wars: Episode I - The Phantom Menace    359544677.0
# 1774  2008                            The Dark Knight    348316061.0

# %%
movies.sort_values(['Net Earnings'],ascending = False)[['Year','Title',"Net Earnings"]].head(10).plot(
    x = 'Title',
    y = 'Net Earnings',
    kind = 'barh'
)
# Out:
# <Axes: ylabel='Title'>

# %% [markdown]
# ### Group BY vs Pivot

# %%
dfGE_01 = movies[['Year', 'Gross Earnings']].groupby(['Year']).sum(numeric_only=True).astype('int64')
dfGE_01
# Out:
#       Gross Earnings
# Year
# 1916               0
# 1920         3000000
# 1925               0
# 1927           26435
# 1929         2817950
# ...              ...
# 2013     10501612904
# 2014     10422826870
# 2015      9513928206
# 2016      5692378656
# 2999         1039304
#
# [92 rows x 1 columns]

# %%
#movies[['Year', 'Gross Earnings']].groupby(['Year']).sum(numeric_only=True).astype('int64').plot()
dfGE_01.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
#dfGE_02 = movies[['Year', 'Gross Earnings']].pivot_table(index=['Year']).astype('int64')
dfGE_02 = pd.pivot_table(movies, index = 'Year', values = 'Gross Earnings', aggfunc = 'sum').astype('int64')
dfGE_02
# Out:
#       Gross Earnings
# Year
# 1916               0
# 1920         3000000
# 1925               0
# 1927           26435
# 1929         2817950
# ...              ...
# 2013     10501612904
# 2014     10422826870
# 2015      9513928206
# 2016      5692378656
# 2999         1039304
#
# [92 rows x 1 columns]

# %%
#movies[['Year', 'Gross Earnings']].pivot_table(index=['Year']).astype('int64').plot()
dfGE_02.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
# Pandas.merge() by Column
dfGE=dfGE_01.join(dfGE_02, lsuffix="_GroupBy", rsuffix="_PivotTable", how='outer')
dfGE
# Out:
#       Gross Earnings_GroupBy  Gross Earnings_PivotTable
# Year
# 1916                       0                          0
# 1920                 3000000                    3000000
# 1925                       0                          0
# 1927                   26435                      26435
# 1929                 2817950                    2817950
# ...                      ...                        ...
# 2013             10501612904                10501612904
# 2014             10422826870                10422826870
# 2015              9513928206                 9513928206
# 2016              5692378656                 5692378656
# 2999                 1039304                    1039304
#
# [92 rows x 2 columns]

# %%
dfGE_03 = movies[['Language','Country','Net Earnings']].groupby(['Country','Language']).sum(numeric_only=True).astype('int64')
dfGE_03
# Out:
#                                  Net Earnings
# Country              Language
# Afghanistan          Dari             1081331
# Argentina            Spanish         16792809
# Aruba                English        -24923864
# Australia            Aboriginal        165429
#                      Dzongkha        -1294705
# ...                                       ...
# USA                  Spanish        -17661918
#                      Vietnamese       -953049
# United Arab Emirates Arabic                 0
# West Germany         English                0
#                      German          -2566866
#
# [127 rows x 1 columns]

# %%
movies.to_excel('Movies2.xlsx',sheet_name='from Pandas with Love')

# %%
movies.to_excel('Movies21.xlsx',index = False, sheet_name='from Pandas with Love')

# %% [markdown]
# #XLSXwriter
# https://xlsxwriter.readthedocs.io/index.html

# %%
#!pip install xlsxwriter --upgrade
# !pip install xlsxwriter
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 2.9 MB/s eta 0:00:00
# ...

# %%
movies.head()
# Out:
#                                                Title  Year  \
# 0  Intolerance: Love's Struggle Throughout the Ages   1916
# 1                    Over the Hill to the Poorhouse   1920
# 2                                    The Big Parade   1925
# 3                                        Metropolis   1927
# 4                                     Pandora's Box   1929
#
#                 Genres Language  Country Content Rating  Duration  \
# 0    Drama|History|War      NaN      USA      Not Rated     123.0
# 1          Crime|Drama      NaN      USA            NaN     110.0
# 2    Drama|Romance|War      NaN      USA      Not Rated     151.0
# 3         Drama|Sci-Fi   German  Germany      Not Rated     145.0
# 4  Crime|Drama|Romance   German  Germany      Not Rated     110.0
#
#    Aspect Ratio     Budget  Gross Earnings  ... Facebook Likes - Actor 2  \
# 0          1.33   385907.0             NaN  ...                     22.0
# ...

# %%
import pandas as pd
import xlsxwriter


# Create a Pandas Excel writer using XlsxWriter as the engine.
writer3 = pd.ExcelWriter('Movies3.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
movies.to_excel(writer3, sheet_name='movies3')
# Close the Pandas Excel writer and output the Excel file.
writer3.close()

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer32 = pd.ExcelWriter('Movies32.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
movies.to_excel(writer32, sheet_name='movies32')
# Close the Pandas Excel writer and output the Excel file.
writer32.close()

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer33 = pd.ExcelWriter('Movies33.xlsx', engine='xlsxwriter')


# Turn off the default header and skip one row to allow us to insert a
# user defined header.
movies.to_excel(writer33, sheet_name='Movies33', startrow=1, header=False)

# Get the xlsxwriter workbook and worksheet objects.
workbook  = writer33.book
worksheet = writer33.sheets['Movies33']

# Add a header format.
header_format = workbook.add_format({
    'bold': True,
    'text_wrap': True,
    'valign': 'top',
    'fg_color': '#D7E4BC',
    'border': 1})

# Write the column headers with the defined format.
for col_num, value in enumerate(movies.columns.values):
    worksheet.write(0, col_num + 1, value, header_format)

# Close the Pandas Excel writer and output the Excel file.
writer33.close()

# %% [markdown]
# #Chronobooks <br>
# Two science fiction novels by Prithwis Mukerjee. A dystopian Earth. A technocratic society managed by artificial intelligence. Escape and epiphany on Mars. Can man and machine, carbon and silicon explore and escape into other dimensions of existence? An Indic perspective rooted in Advaita Vedanta and the Divine Feminine.  [More information](http://bit.ly/chronobooks) <br>
# ![alt text](https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEg8qElM73l6qtmIS1VTUgsLLhyoGnbWGDq8g-v-g2iW1xr-IRr7FT9WW4tnKDY2sE1rJKPl7sp_p_f6ipEs-__eYU7V0SRuoLlhkopL063bEPqUTiC4lrM4toFMgaf7kpxE2m5niHwn7jZwb9ktv8OdO7OIwPL9xyyF-SiSuQE2SRemLVQRCalwDnQgdg/s16000/CTCYFooter-1.png)
